# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.8/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_ROBOFLOW_API_KEY")
project = rf.workspace("fatimas-workspace-opykw").project("my-first-project-9anvz")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 135.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 6.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-1 in yolo26:: 100%|██████████| 381/381 [00:00<00:00, 9374.37it/s]

# %%
# !yolo train model=yolo26n.pt data='/content/My-First-Project-1/data.yaml' epochs=200 imgsz=640
# Out:
# ...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/My-First-Project-1/test/images/images-5-_jpg.rf.f64020df9287d28f894509b53f166bad.jpg"
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.3 GFLOPs
#
# image 1/1 /content/My-First-Project-1/test/images/images-5-_jpg.rf.f64020df9287d28f894509b53f166bad.jpg: 640x640 1 spiderman, 10.7ms
# Speed: 29.6ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict-4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **I made generalization and tried on test data**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
